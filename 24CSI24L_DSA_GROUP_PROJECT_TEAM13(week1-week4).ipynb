# %% [markdown]
# ## 24ADI204 DATA SCIENCE AND VISULIZATION
#
#
# ### PROBLEM STATEMENT :
# #### Smart Farming Analytics: Crop Recommendation and Agricultural Condition Analysis
#
# ### Domain:
# #### Agriculture & Smart Farming
#
#
#
# ### Dataset Source:
# **Dataset Name:** Smart Farming Recommendation Dataset
#
# **Source:** User-provided CSV dataset
#
# **Dataset link:** https://www.kaggle.com/datasets/hariharank2205/smart-agriculture
#
#
# **Dataset file:** 'C:\Users\ELCOT\Documents\SmartFarming_recommendation.csv'
#
# ### SDG Aligned
# **SDG 2 – Zero Hunger**
#
# This project is aligned with Sustainable Development Goal 2 by using data-driven analysis to support crop recommendation, efficient resource use, and improved agricultural decision-making.
#
# ### Team Number: 13
#
# ### Team Members:
# Hadhish R
#
# Hariharan K
#
# Prasanna M
#
# Siva Deepan A

# %% [markdown]
# ### Objective of Week 2
# The objective of this week's work is to understand the raw dataset before performing data cleaning and Exploratory Data Analysis (EDA). The dataset will be inspected to understand its size, structure, features, data types, missing values, duplicate records, and overall data quality.
#
# # 1. Import Required Libraries and Load the Dataset
#
# **Purpose:** Import the libraries required for data analysis and visualization and Load the raw dataset into a Pandas DataFrame for analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\ELCOT\Documents\SmartFarming_recommendation.csv")

# %% [markdown]
# # 2. View Sample Records
#
# **Purpose:** Get an initial view of the dataset and its values and also the final view

# %%
df.head()
# Out:
#       N     P     K  temperature   humidity        ph    rainfall label  \
# 0  90.0  42.0  43.0    20.879744  82.002744  6.502985  202.935536  rice
# 1  85.0  58.0  41.0    21.770462  80.319644  7.038096  226.655537  rice
# 2  60.0  55.0  44.0          NaN  82.320763  7.840207  263.964248  rice
# 3  74.0  35.0  40.0    26.491096  80.158363  6.980401  242.864034  rice
# 4  78.0  42.0  42.0    20.130175  81.604873  7.628473  262.717340  rice
#
#    soil_moisture  soil_type  ...  organic_matter  irrigation_frequency  \
# 0      29.446064        2.0  ...        3.121395                   4.0
# 1      12.851183        3.0  ...        2.142021                   4.0
# 2      29.363913        2.0  ...        1.474974                   1.0
# 3      26.207732        3.0  ...        8.393907                   1.0
# 4      28.236236        2.0  ...             NaN                   3.0
#
#    crop_density  pest_pressure  fertilizer_usage  growth_stage  \
# ...

# %%
df.tail()
# Out:
#        N     P     K  temperature   humidity        ph    rainfall  \
# 2305 NaN  64.0  16.0    16.433403        NaN  5.926677  140.371781
# 2306 NaN   NaN  53.0          NaN  84.608083  6.211749   42.006603
# 2307 NaN  82.0  45.0    25.293915  79.291222  5.614471  105.422025
# 2308 NaN  63.0  19.0    19.347944  55.968055  4.681576  194.592115
# 2309 NaN   NaN  21.0    31.019636  49.976752  3.532009   32.812965
#
#             label  soil_moisture  soil_type  ...  organic_matter  \
# 2305  kidneybeans      25.651886        2.0  ...        9.521419
# 2306   watermelon      17.992056        1.0  ...        9.853923
# 2307       banana      15.584397        2.0  ...        8.628985
# 2308   pigeonpeas      28.003393        2.0  ...        4.360637
# 2309    mothbeans      16.289118        2.0  ...        9.792096
#
#       irrigation_frequency  crop_density  pest_pressure  fertilizer_usage  \
# 2305                   1.0      8.559229      12.564164        148.332914
# ...

# %% [markdown]
# # 3. Check Dataset Shape and Check Column Names
#
# **Purpose:** Identify the number of rows and columns in the dataset and Identify all available features in the dataset.

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Rows: 2310
# Columns: 23
#
# Column Names:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label', 'soil_moisture', 'soil_type', 'sunlight_exposure', 'wind_speed', 'co2_concentration', 'organic_matter', 'irrigation_frequency', 'crop_density', 'pest_pressure', 'fertilizer_usage', 'growth_stage', 'urban_area_proximity', 'water_source_type', 'frost_risk', 'water_usage_efficiency']

# %% [markdown]
# # 4. Check Dataset Information
#
# **Purpose:** Understand the dataset structure, data types, and non-null values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   N                       2090 non-null   float64
#  1   P                       2194 non-null   float64
#  2   K                       2194 non-null   float64
#  3   temperature             2196 non-null   float64
#  4   humidity                2196 non-null   float64
#  5   ph                      2196 non-null   float64
#  6   rainfall                2196 non-null   float64
#  7   label                   2310 non-null   object
#  8   soil_moisture           2193 non-null   float64
#  9   soil_type               2193 non-null   float64
#  10  sunlight_exposure       2196 non-null   float64
#  11  wind_speed              2194 non-null   float64
#  12  co2_concentration       2196 non-null   float64
#  13  organic_matter          2191 non-null   float64
# ...

# %% [markdown]
# # 5. Identify Feature Types
#
# **Purpose:** Separate numerical and categorical features for further analysis.

# %%
numerical_cols = df.select_dtypes(
    include=np.number
).columns.tolist()

categorical_cols = df.select_dtypes(
    include=["object", "string", "category"]
).columns.tolist()

print("Numerical Features:")
print(numerical_cols)

print("\nCategorical Features:")
print(categorical_cols)
# Out:
# Numerical Features:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'soil_moisture', 'soil_type', 'sunlight_exposure', 'wind_speed', 'co2_concentration', 'organic_matter', 'irrigation_frequency', 'crop_density', 'pest_pressure', 'fertilizer_usage', 'growth_stage', 'urban_area_proximity', 'water_source_type', 'frost_risk', 'water_usage_efficiency']
#
# Categorical Features:
# ['label']

# %% [markdown]
# # 6. Check Missing Values
#
# **Purpose:** Identify missing values and assess data completeness.

# %%
df.isnull().sum()
# Out:
# N                         220
# P                         116
# K                         116
# temperature               114
# humidity                  114
# ph                        114
# rainfall                  114
# label                       0
# soil_moisture             117
# soil_type                 117
# sunlight_exposure         114
# wind_speed                116
# co2_concentration         114
# organic_matter            119
# irrigation_frequency      118
# crop_density              117
# pest_pressure             115
# fertilizer_usage          113
# growth_stage              117
# urban_area_proximity      119
# water_source_type         114
# frost_risk                112
# water_usage_efficiency    116
# dtype: int64

# %% [markdown]
# # 7. Check Duplicate Records
#
# **Purpose:** Identify duplicate observations in the dataset.

# %%
df.duplicated().sum()
# Out:
# np.int64(110)

# %% [markdown]
# # 8. Check Unique Values
#
# **Purpose:** Identify the number of unique values in each feature.

# %%
df.nunique()
# Out:
# N                          137
# P                          117
# K                           73
# temperature               2090
# humidity                  2090
# ph                        2090
# rainfall                  2090
# label                       22
# soil_moisture             2090
# soil_type                    3
# sunlight_exposure         2090
# wind_speed                2090
# co2_concentration         2090
# organic_matter            2090
# irrigation_frequency         6
# crop_density              2090
# pest_pressure             2090
# fertilizer_usage          2090
# growth_stage                 3
# urban_area_proximity      2090
# water_source_type            3
# frost_risk                2090
# water_usage_efficiency    2090
# dtype: int64

# %% [markdown]
# # 9. Statistical Summary
#
# **Purpose:** Understand the basic statistical characteristics of numerical features.

# %%
df.describe(include="all")
# Out:
#                   N            P            K  temperature     humidity  \
# count   2090.000000  2194.000000  2194.000000  2196.000000  2196.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      50.548325    53.066089    47.326345    25.671178    71.518719
# std       37.027836    32.736783    49.735967     5.009890    22.235590
# min        0.000000     5.000000     5.000000     8.825675    14.258040
# 25%       21.000000    28.000000    20.000000    22.851637    60.261953
# 50%       37.000000    51.000000    31.000000    25.656980    80.454888
# 75%       85.000000    68.000000    48.000000    28.572096    90.026054
# max      140.000000   145.000000   205.000000    43.675493    99.981876
#
#                  ph     rainfall   label  soil_moisture    soil_type  ...  \
# ...

# %% [markdown]
# # 10. Check Constant Columns
#
# **Purpose:** Identify columns with only one unique value.

# %%
constant_columns = [
    col for col in df.columns
    if df[col].nunique() == 1
]

print(constant_columns)
# Out:
# []

# %% [markdown]
# # 11. Data Quality Summary
#
# **Purpose:** Summarize the quality and characteristics of each feature.

# %%
data_quality_report = pd.DataFrame({
    "Data Type": df.dtypes,
    "Missing Values": df.isnull().sum(),
    "Missing %": ((df.isnull().sum() / len(df)) * 100).round(2),
    "Unique Values": df.nunique()
})

data_quality_report
# Out:
#                        Data Type  Missing Values  Missing %  Unique Values
# N                        float64             220       9.52            137
# P                        float64             116       5.02            117
# K                        float64             116       5.02             73
# temperature              float64             114       4.94           2090
# humidity                 float64             114       4.94           2090
# ph                       float64             114       4.94           2090
# rainfall                 float64             114       4.94           2090
# label                     object               0       0.00             22
# soil_moisture            float64             117       5.06           2090
# soil_type                float64             117       5.06              3
# sunlight_exposure        float64             114       4.94           2090
# ...

# %% [markdown]
# ### Week 2 Conclusion
#
# The raw dataset was successfully inspected to understand its structure, features, data types, missing values, duplicates, and overall data quality.
#
# The next stage will focus on data cleaning and preparation.

# %% [markdown]
# # Week 3: Data Cleaning
#
# **Objective:** Clean the dataset by fixing inconsistent values, correcting data types, handling missing values, checking duplicates, and detecting potential outliers.
#
# # 1. Initial Data Quality Check
#
# **Purpose:** Record the condition of the dataset before cleaning.

# %%
df_cleaned = df.copy()
print("Dataset Shape:", df_cleaned.shape)
print("Total Missing Values:", df_cleaned.isnull().sum().sum())
print("Duplicate Records:", df_cleaned.duplicated().sum())
# Out:
# Dataset Shape: (2310, 23)
# Total Missing Values: 2646
# Duplicate Records: 110

# %% [markdown]
# # 2. Clean Categorical Values
#
# **Purpose:** Remove unnecessary spaces and tab characters from categorical values.

# %%
categorical_columns = df.select_dtypes(
    include=["object", "string", "category"]
).columns.tolist()

for col in categorical_columns:
    df_cleaned[col] = (
        df_cleaned[col]
        .astype("string")
        .str.strip()
        .str.lower()
    )

print("Categorical columns cleaned:")
print(categorical_columns)
# Out:
# Categorical columns cleaned:
# ['label']

# %% [markdown]
# # 3. Verify Categorical Values
#
# **Purpose:** Check whether categorical values are consistently formatted.

# %%
for col in categorical_columns:
    print(f"\n{col}:")
    print(df_cleaned[col].unique())
# Out:
# label:
# <StringArray>
# [       'rice',       'maize',    'chickpea', 'kidneybeans',  'pigeonpeas',
#    'mothbeans',    'mungbean',   'blackgram',      'lentil', 'pomegranate',
#       'banana',       'mango',      'grapes',  'watermelon',   'muskmelon',
#        'apple',      'orange',      'papaya',     'coconut',      'cotton',
#         'jute',      'coffee']
# Length: 22, dtype: string

# %% [markdown]
# # 4. Convert Incorrect Data Types
#
# **Purpose:** Convert numerical values stored as text into numeric data types.

# %%
# Convert all non-categorical columns to numeric where applicable.
# Any invalid numeric values will become NaN.
for col in df_cleaned.columns:
    if col not in categorical_columns:
        df_cleaned[col] = pd.to_numeric(
            df_cleaned[col],
            errors="coerce"
        )

print(df_cleaned.dtypes)
# Out:
# N                                float64
# P                                float64
# K                                float64
# temperature                      float64
# humidity                         float64
# ph                               float64
# rainfall                         float64
# label                     string[python]
# soil_moisture                    float64
# soil_type                        float64
# sunlight_exposure                float64
# wind_speed                       float64
# co2_concentration                float64
# organic_matter                   float64
# irrigation_frequency             float64
# crop_density                     float64
# pest_pressure                    float64
# fertilizer_usage                 float64
# growth_stage                     float64
# urban_area_proximity             float64
# water_source_type                float64
# frost_risk                       float64
# water_usage_efficiency           float64
# ...

# %% [markdown]
# # 5. Check Missing Values
#
# **Purpose:** Identify missing values after correcting data types.

# %%
missing_summary = pd.DataFrame({
    "Missing Values": df_cleaned.isnull().sum(),
    "Missing Percentage": (
        df_cleaned.isnull().sum() / len(df_cleaned) * 100
    ).round(2)
})

missing_summary
# Out:
#                         Missing Values  Missing Percentage
# N                                  220                9.52
# P                                  116                5.02
# K                                  116                5.02
# temperature                        114                4.94
# humidity                           114                4.94
# ph                                 114                4.94
# rainfall                           114                4.94
# label                                0                0.00
# soil_moisture                      117                5.06
# soil_type                          117                5.06
# sunlight_exposure                  114                4.94
# wind_speed                         116                5.02
# co2_concentration                  114                4.94
# organic_matter                     119                5.15
# irrigation_frequency               118                5.11
# ...

# %% [markdown]
# # 6. Identify Feature Types
#
# **Purpose:** Separate numerical and categorical features for appropriate data cleaning.

# %%
numerical_cols = df_cleaned.select_dtypes(
    include=np.number
).columns.tolist()

categorical_cols = df_cleaned.select_dtypes(
    include=["object", "string", "category"]
).columns.tolist()

print("Numerical Features:")
print(numerical_cols)

print("\nCategorical Features:")
print(categorical_cols)
# Out:
# Numerical Features:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'soil_moisture', 'soil_type', 'sunlight_exposure', 'wind_speed', 'co2_concentration', 'organic_matter', 'irrigation_frequency', 'crop_density', 'pest_pressure', 'fertilizer_usage', 'growth_stage', 'urban_area_proximity', 'water_source_type', 'frost_risk', 'water_usage_efficiency']
#
# Categorical Features:
# ['label']

# %% [markdown]
# # 7. Handle Numerical Missing Values
#
# **Purpose:** Replace missing numerical values using the median.
#
# **Reason:** The median is less affected by extreme values.

# %%
for col in numerical_cols:
    if df_cleaned[col].isnull().sum() > 0:
        df_cleaned[col] = df_cleaned[col].fillna(
            df_cleaned[col].median()
        )

# %% [markdown]
# # 8. Handle Categorical Missing Values
#
# **Purpose:** Replace missing categorical values using the mode.
#
# **Reason:** The mode represents the most frequently occurring category.

# %%
for col in categorical_cols:
    if df_cleaned[col].isnull().sum() > 0:
        df_cleaned[col] = df_cleaned[col].fillna(
            df_cleaned[col].mode()[0]
        )

# %% [markdown]
# # 9. Verify Missing Values
#
# **Purpose:** Confirm that missing values have been handled successfully.

# %%
print("Total Missing Values:")
print(df_cleaned.isnull().sum().sum())

print("\nMissing Values by Column:")
print(df_cleaned.isnull().sum())
# Out:
# Total Missing Values:
# 0
#
# Missing Values by Column:
# N                         0
# P                         0
# K                         0
# temperature               0
# humidity                  0
# ph                        0
# rainfall                  0
# label                     0
# soil_moisture             0
# soil_type                 0
# sunlight_exposure         0
# wind_speed                0
# co2_concentration         0
# organic_matter            0
# irrigation_frequency      0
# crop_density              0
# pest_pressure             0
# fertilizer_usage          0
# growth_stage              0
# urban_area_proximity      0
# water_source_type         0
# frost_risk                0
# water_usage_efficiency    0
# dtype: int64

# %% [markdown]
# # 10. Update Feature Lists
#
# **Purpose:** Confirm the numerical and categorical features before outlier detection.

# %%
numerical_cols = df_cleaned.select_dtypes(
    include=np.number
).columns.tolist()

categorical_cols = df_cleaned.select_dtypes(
    include=["object", "string", "category"]
).columns.tolist()

print("Numerical Features:")
print(numerical_cols)

print("\nCategorical Features:")
print(categorical_cols)

df_cleaned.to_csv("SmartFarming_cleaned.csv", index=False)
print("\nCleaned dataset saved as SmartFarming_cleaned.csv")
# Out:
# Numerical Features:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'soil_moisture', 'soil_type', 'sunlight_exposure', 'wind_speed', 'co2_concentration', 'organic_matter', 'irrigation_frequency', 'crop_density', 'pest_pressure', 'fertilizer_usage', 'growth_stage', 'urban_area_proximity', 'water_source_type', 'frost_risk', 'water_usage_efficiency']
#
# Categorical Features:
# ['label']
#
# Cleaned dataset saved as SmartFarming_cleaned.csv

# %% [markdown]
# # 11. Outlier Detection Using Boxplots
#
# **Purpose:** Visually identify potential outliers in numerical farming features.

# %%
for col in numerical_cols:
    plt.figure(figsize=(8, 4))

    df_cleaned.boxplot(column=col)

    plt.title(f"Boxplot of {col}")
    plt.ylabel(col)

    plt.show()

# %% [markdown]
# Histogram for Outlier Detection
# Purpose:
# A histogram shows the distribution of numerical values. It helps identify unusually high or low values that may indicate potential outliers.

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    plt.hist(df[col].dropna(), bins=30, edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# # 12. Outlier Detection Using Z-Score
#
# **Purpose:** Identify observations that significantly deviate from the mean.
#
# A Z-score greater than 3 or less than -3 is considered a potential outlier.

# %%
all_numerical_cols = df.select_dtypes(include='number').columns

z_score_df = pd.DataFrame(index=df.index)

for col in all_numerical_cols:
    mean = df[col].mean()
    std = df[col].std()

    z_score_df[col] = (df[col] - mean) / std

z_outlier_mask = z_score_df.abs() > 3

z_outlier_report = pd.DataFrame({
    "Outlier Count": z_outlier_mask.sum(),
    "Outlier Percentage": (
        z_outlier_mask.sum() / len(df)
    ) * 100
})

z_outlier_report
# Out:
#                         Outlier Count  Outlier Percentage
# N                                   0            0.000000
# P                                   0            0.000000
# K                                 151            6.536797
# temperature                        34            1.471861
# humidity                            0            0.000000
# ph                                 32            1.385281
# rainfall                           23            0.995671
# soil_moisture                       0            0.000000
# soil_type                           0            0.000000
# sunlight_exposure                   0            0.000000
# wind_speed                          0            0.000000
# co2_concentration                   0            0.000000
# organic_matter                      0            0.000000
# irrigation_frequency                0            0.000000
# crop_density                        0            0.000000
# ...

# %% [markdown]
# #12. Outlier Detection Using IQR
#
# **Purpose:** Identify observations that significantly deviate from the middle 50% of the data.
#
# An observation is considered a potential outlier if it is below Q1 − 1.5 × IQR or above Q3 + 1.5 × IQR.

# %%
# IQR Outlier Detection

import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv(r"C:\Users\ELCOT\Documents\SmartFarming_recommendation.csv")

# Select numerical columns
numerical_cols = df.select_dtypes(include=np.number).columns

# Create outlier mask
iqr_outlier_mask = pd.DataFrame(index=df.index)

# Detect outliers using IQR
for col in numerical_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    iqr_outlier_mask[col] = (
        (df[col] < lower_bound) |
        (df[col] > upper_bound)
    )

# Create outlier report
iqr_outlier_report = pd.DataFrame({
    "Outlier Count": iqr_outlier_mask.sum(),
    "Outlier Percentage":
        (iqr_outlier_mask.sum() / len(df)) * 100
})

# Display report
print("IQR Outlier Report:")
display(iqr_outlier_report)
# Out:
# IQR Outlier Report:
#                         Outlier Count  Outlier Percentage
# N                                   0            0.000000
# P                                 132            5.714286
# K                                 191            8.268398
# temperature                        83            3.593074
# humidity                           30            1.298701
# ph                                 60            2.597403
# rainfall                           97            4.199134
# soil_moisture                       0            0.000000
# soil_type                           0            0.000000
# sunlight_exposure                   0            0.000000
# wind_speed                          0            0.000000
# co2_concentration                   0            0.000000
# organic_matter                      0            0.000000
# irrigation_frequency                0            0.000000
# crop_density                        0            0.000000
# ...

# %%
numerical_cols = df.select_dtypes(include='number').columns

iqr_outlier_mask = pd.DataFrame(index=df.index)

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    iqr_outlier_mask[col] = (
        (df[col] < lower_bound) |
        (df[col] > upper_bound)
    )

iqr_outlier_report = pd.DataFrame({
    "Outlier Count": iqr_outlier_mask.sum(),
    "Outlier Percentage": (
        iqr_outlier_mask.sum() / len(df)
    ) * 100
})

iqr_outlier_report
# Out:
#                         Outlier Count  Outlier Percentage
# N                                   0            0.000000
# P                                 132            5.714286
# K                                 191            8.268398
# temperature                        83            3.593074
# humidity                           30            1.298701
# ph                                 60            2.597403
# rainfall                           97            4.199134
# soil_moisture                       0            0.000000
# soil_type                           0            0.000000
# sunlight_exposure                   0            0.000000
# wind_speed                          0            0.000000
# co2_concentration                   0            0.000000
# organic_matter                      0            0.000000
# irrigation_frequency                0            0.000000
# crop_density                        0            0.000000
# ...

# %% [markdown]
# # Week 4 – Exploratory Data Analysis (EDA)
#
# **Project:** Smart Farming Analytics
#
# **Objective:** Perform Week 4 EDA using Univariate and Bivariate analysis and visualize distributions as required by the DSV Rule Book.

# %%
# 1. Load Dataset and Prepare Feature Groups
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\ELCOT\Documents\SmartFarming_recommendation.csv")

target = 'label'

# These columns contain coded categories in the CSV
categorical_cols = ['soil_type', 'irrigation_frequency', 'growth_stage', 'water_source_type']
categorical_cols = [c for c in categorical_cols if c in df.columns]

continuous_cols = [
    c for c in df.select_dtypes(include=np.number).columns
    if c not in categorical_cols
]

print('Dataset Shape:', df.shape)
print('\nContinuous Features:', continuous_cols)
print('\nCategorical Features:', categorical_cols)
print('\nTarget:', target)
# Out:
# Dataset Shape: (2310, 23)
#
# Continuous Features: ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'soil_moisture', 'sunlight_exposure', 'wind_speed', 'co2_concentration', 'organic_matter', 'crop_density', 'pest_pressure', 'fertilizer_usage', 'urban_area_proximity', 'frost_risk', 'water_usage_efficiency']
#
# Categorical Features: ['soil_type', 'irrigation_frequency', 'growth_stage', 'water_source_type']
#
# Target: label

# %%
# 2. Univariate Analysis – Target and Categorical Features
print('Crop Distribution')
print(df[target].value_counts())

plt.figure(figsize=(10, 6))
sns.countplot(y=target, data=df, order=df[target].value_counts().index)
plt.title('Distribution of Crops')
plt.xlabel('Number of Records')
plt.ylabel('Crop')
plt.tight_layout()
plt.show()

for col in categorical_cols:
    plt.figure(figsize=(7, 4))
    sns.countplot(x=df[col])
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.tight_layout()
    plt.show()
# Out:
# Crop Distribution
# label
# papaya         109
# blackgram      108
# mothbeans      107
# orange         107
# muskmelon      106
# pigeonpeas     106
# coconut        106
# coffee         106
# jute           106
# maize          105
# watermelon     105
# chickpea       104
# rice           104
# kidneybeans    104
# mungbean       104
# lentil         104
# banana         104
# pomegranate    104
# apple          104
# mango          103
# cotton         103
# grapes         101
# Name: count, dtype: int64

# %%
# 3. Univariate Analysis – Numerical Distributions
# Histograms with KDE show the shape of each numerical feature.
for col in continuous_cols:
    plt.figure(figsize=(7, 4))
    sns.histplot(df[col].dropna(), bins=30, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
# 4. Univariate Analysis – Boxplots and Descriptive Statistics
print('Descriptive Statistics')
stats = df[continuous_cols].describe().T
stats['Median'] = df[continuous_cols].median()
stats['Skewness'] = df[continuous_cols].skew()
stats['Kurtosis'] = df[continuous_cols].kurtosis()
display(stats.round(2))

for col in continuous_cols:
    plt.figure(figsize=(7, 3.5))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()
# Out:
# Descriptive Statistics
#                          count    mean    std     min     25%     50%     75%  \
# N                       2090.0   50.55  37.03    0.00   21.00   37.00   85.00
# P                       2194.0   53.07  32.74    5.00   28.00   51.00   68.00
# K                       2194.0   47.33  49.74    5.00   20.00   31.00   48.00
# temperature             2196.0   25.67   5.01    8.83   22.85   25.66   28.57
# humidity                2196.0   71.52  22.24   14.26   60.26   80.45   90.03
# ph                      2196.0    6.47   0.78    3.50    5.98    6.43    6.93
# rainfall                2196.0  103.47  55.20   20.21   64.24   94.70  124.27
# soil_moisture           2193.0   20.17   5.80   10.02   15.20   20.16   25.31
# sunlight_exposure       2196.0    8.58   2.00    5.00    6.93    8.62   10.26
# wind_speed              2194.0   10.14   5.73    0.00    5.24   10.26   14.99
# co2_concentration       2196.0  399.66  28.33  350.00  375.44  399.74  424.12
# ...

# %%
# 5. Bivariate Analysis – Correlation Heatmap
corr = df[continuous_cols].corr()

plt.figure(figsize=(12, 9))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlation Heatmap of Numerical Features')
plt.tight_layout()
plt.show()

# Show strongest positive/negative relationships
mask = np.triu(np.ones(corr.shape), k=1).astype(bool)
pairs = corr.where(mask).stack().sort_values(key=abs, ascending=False)
print('\nTop 10 Correlated Feature Pairs:')
print(pairs.head(10).round(2))
# Out:
# Top 10 Correlated Feature Pairs:
# P            K              0.73
# N            P             -0.23
# temperature  humidity       0.22
# K            humidity       0.19
# N            humidity       0.19
# K            ph            -0.18
#              temperature   -0.14
# P            ph            -0.14
# N            K             -0.14
# P            temperature   -0.13
# dtype: float64

# %%
# 6. Bivariate Analysis – Important Features vs Crop
key_features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
key_features = [c for c in key_features if c in df.columns]

for col in key_features:
    plt.figure(figsize=(12, 4))
    sns.boxplot(x=target, y=col, data=df)
    plt.title(f'{col} vs Crop')
    plt.xlabel('Crop')
    plt.ylabel(col)
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
# 7. Bivariate Analysis – Scatter Plots
scatter_pairs = [
    ('N', 'P'),
    ('temperature', 'humidity'),
    ('rainfall', 'humidity'),
    ('ph', 'rainfall')
]

for x, y in scatter_pairs:
    if x in df.columns and y in df.columns:
        plt.figure(figsize=(7, 5))
        sns.scatterplot(data=df, x=x, y=y, hue=target, alpha=0.6, legend=False)
        plt.title(f'{x} vs {y}')
        plt.xlabel(x)
        plt.ylabel(y)
        plt.tight_layout()
        plt.show()

# %%
# 8. Automated EDA Summary
print('=' * 55)
print('AUTOMATED EDA SUMMARY')
print('=' * 55)

print('\n1. Dataset Size')
print('Rows:', df.shape[0])
print('Columns:', df.shape[1])

print('\n2. Missing Values')
print('Total:', df.isnull().sum().sum())

print('\n3. Duplicate Records')
print(df.duplicated().sum())

print('\n4. Numerical Summary')
summary = pd.DataFrame({
    'Mean': df[continuous_cols].mean(),
    'Median': df[continuous_cols].median(),
    'Std Dev': df[continuous_cols].std(),
    'Skewness': df[continuous_cols].skew(),
    'Kurtosis': df[continuous_cols].kurtosis()
})
display(summary.round(2))

print('\n5. Crop Classes:', df[target].nunique())
print('\n6. Crop Counts:')
print(df[target].value_counts())

print('\n7. Most Strongly Related Numerical Features')
print(pairs.head(5).round(2))

print('\nEDA COMPLETED')
# Out:
# ...
# AUTOMATED EDA SUMMARY
# ...
#
# 1. Dataset Size
# Rows: 2310
# Columns: 23
#
# 2. Missing Values
# Total: 2646
#
# 3. Duplicate Records
# 110
#
# 4. Numerical Summary
#                           Mean  Median  Std Dev  Skewness  Kurtosis
# N                        50.55   37.00    37.03      0.51     -1.06
# P                        53.07   51.00    32.74      1.01      0.89
# K                        47.33   31.00    49.74      2.44      4.82
# temperature              25.67   25.66     5.01      0.18      1.23
# humidity                 71.52   80.45    22.24     -1.09      0.32
# ph                        6.47    6.43     0.78      0.28      1.79
# rainfall                103.47   94.70    55.20      0.97      0.61
# soil_moisture            20.17   20.16     5.80     -0.02     -1.22
# sunlight_exposure         8.58    8.62     2.00     -0.07     -1.14
# wind_speed               10.14   10.26     5.73     -0.05     -1.20
# ...

# %% [markdown]
# ## Week 4 Conclusion
#
# The Smart Farming dataset was explored using **univariate analysis** (crop/categorical distributions, histograms, boxplots, descriptive statistics) and **bivariate analysis** (correlation heatmap, feature-vs-crop boxplots and scatter plots). The automated EDA summary collects the main numerical findings for the project report.
